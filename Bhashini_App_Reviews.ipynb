# %% [markdown]
# <a href="https://colab.research.google.com/github/danihak/Bhashini2/blob/main/Bhashini_App_Reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper #Scrappingreviews
# !pip install -q transformers #Sentiment
# !pip install -q plotly-express #DataVisualization

# %%
# !pip install google-play-scraper
from google_play_scraper import reviews_all, Sort

# %%
pip install PyYAML==6.0.1

# %%
! pip show google-play-scrapper
# Out:
# WARNING: Package(s) not found: google-play-scrapper

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews_all
import plotly.express as px

# %%
print(sleep_milliseconds)  # Check if the variable is defined
print(lang)  # Check if the variable is defined
print(country)  # Check if the variable is defined
print(sort)  # Check if the variable is defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-64e526d01c9b> in <cell line: 1>()
# ----> 1 print(sleep_milliseconds)  # Check if the variable is defined
#       2 print(lang)  # Check if the variable is defined
#       3 print(country)  # Check if the variable is defined
#       4 print(sort)  # Check if the variable is defined
#
# NameError: name 'sleep_milliseconds' is not defined

# %%
bhashini_app = reviews_all ( 'com.dibd.bhashini', sleep_milliseconds-0, lang -'en_IN',country-'IN', sort-Sort.NEWEST)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fd746a13d959> in <cell line: 1>()
# ----> 1 bhashini_app = reviews_all ( 'com.dibd.bhashini', sleep_milliseconds-0, lang -'en_IN',country-'IN', sort-Sort.NEWEST)
#
# NameError: name 'sleep_milliseconds' is not defined

# %%
# Change sleep_milliseconds to sleep_milliseconds
# Change lang to lang
# Change country to country
# Change sort to sort

bhashini_app = reviews_all(
    'com.dibd.bhashini',
    sleep_milliseconds=0,
    lang='en_IN',
    sort=Sort.RATING
)

# %%
print(bhashini_app)
# Out:
# [{'reviewId': 'f2c04441-6efa-49a8-95a1-74b4eb35aeb1', 'userName': 'mahesh patel', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJh3AYS1PJxfSzcQWRZY_4Ql7OStv-ZNrfnFzuqG2Nq=mo', 'content': '👍', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '2.3.5', 'at': datetime.datetime(2024, 2, 25, 8, 25, 12), 'replyContent': None, 'repliedAt': None, 'appVersion': '2.3.5'}, {'reviewId': 'ef857868-bb7a-4cdb-b143-5a93a4726bb1', 'userName': 'Amit Kumar', 'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK2IsmBrp_eeR4ff9THJ01PHVKokWTES-Aypvf6vL2XNA=mo', 'content': 'ये बहुत गर्व है कि हमरी सरकार ने भारतीय लोग को इस के साथ एक किया है। , My suggestion for this app maker, please make a translation History record in this app.', 'score': 5, 'thumbsUpCount': 0, 'reviewCreatedVersion': '2.3.5', 'at': datetime.datetime(2024, 2, 25, 5, 7, 32), 'replyContent': None, 'repliedAt': None, 'appVersion': '2.3.5'}, {'reviewId': 'ab5da914-a547-4f98-888a-5a342aa4f508', 'userName': 'Parsu G
# ...

# %%
df = pd.json_normalize(bhashini_app)

# %%
df.head()
# Out:
#                                reviewId           userName  \
# 0  2677e4b2-5a79-4f2e-b725-a6b0f709b0ac       Suril Pandya
# 1  2e5b49f4-c680-43cd-8ab1-75b621411709        ajit pandey
# 2  22af0767-a501-4439-a9e8-2e87fcb2795e  sanjaya panigrahy
# 3  01c2344b-fd3a-425d-a3e0-4d3c6c4c518f        TheGood Guy
# 4  5d267699-c72f-4be1-b77c-3a65a49ec5a3        Vikas Anand
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Awesomesauce! Loved the simplicity, ease and s...      5              0
# 1  Good app, translation and voice recognition is...      5              1
# ...

# %%
df.shape
# Out:
# (796, 11)

# %%
df.to_csv('bhashini_app.csv', index=False)

# %%
bhashini_app.csv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-32f65d17878a> in <cell line: 1>()
# ----> 1 bhashini_app.csv
#
# AttributeError: 'list' object has no attribute 'csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/MyDrive/bhashini_app/bhashini_app.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-31-f2ee47a40d1b> in <cell line: 1>()
# ----> 1 df.to_csv('/content/drive/MyDrive/bhashini_app/bhashini_app.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
# ...

# %%
# !mkdir /content/drive/MyDrive/bhashini_app

# %%
df.to_csv('/content/drive/MyDrive/bhashini_app/bhashini_app.csv', index=False)

# %%
# Change sleep_milliseconds to sleep_milliseconds
# Change lang to lang
# Change country to country
# Change sort to sort

bhashini_app = reviews_all(
    'com.dibd.bhashini',
    sleep_milliseconds=0,
    lang='en_IN',
    country='IN',
    sort=Sort.OLDEST
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1caa270fde42> in <cell line: 6>()
#       9     lang='en_IN',
#      10     country='IN',
# ---> 11     sort=Sort.OLDEST
#      12 )
#
# /usr/lib/python3.10/enum.py in __getattr__(cls, name)
#     435             return cls._member_map_[name]
#     436         except KeyError:
# --> 437             raise AttributeError(name) from None
#     438
#     439     def __getitem__(cls, name):
#
# AttributeError: OLDEST

# %%
# !pip install enum34

import enum

class Sort(enum.Enum):
    MOST_RELEVANT = 0
    NEWEST = 1
    OLDEST = 2

bhashini_app = reviews_all(
    'com.dibd.bhashini',
    sleep_milliseconds=0,
    lang='en_IN',
    country='IN',
    sort=Sort.NEWEST
)

# %%
# Change sleep_milliseconds to sleep_milliseconds
# Change lang to lang
# Change country to country
# Change sort to sort

bhashini_app = reviews_all(
    'com.dibd.bhashini',
    sleep_milliseconds=0,
    lang='en_IN',
    country='US',
    count = 7,
    sort=Sort.NEWEST
)

# %%
df2 = pd.json_normalize(bhashini_app)

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-68302b2f4bd0> in <cell line: 1>()
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
df2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4790437ebfac> in <cell line: 1>()
# ----> 1 df2.shape
#
# NameError: name 'df2' is not defined

# %%
df.shape
# Out:
# (199, 11)

# %%
pagination_token = None
while True:
    reviews, pagination_token = reviews_all(
        'com.dibd.bhashini',
        sleep_milliseconds=0,
        lang='en_IN',
        country='IN',
        sort=Sort.NEWEST,
        pagination_token=pagination_token
    )

    # Process the reviews

    if pagination_token is None:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-13a9edaf7421> in <cell line: 2>()
#       1 pagination_token = None
#       2 while True:
# ----> 3     reviews, pagination_token = reviews_all(
#       4         'com.dibd.bhashini',
#       5         sleep_milliseconds=0,
#
# /usr/local/lib/python3.10/dist-packages/google_play_scraper/features/reviews.py in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     149
#     150     while True:
# --> 151         _result, continuation_token = reviews(
#     152             app_id,
#     153             count=MAX_COUNT_EACH_FETCH,
#
# TypeError: reviews() got an unexpected keyword argument 'pagination_token'

# %%
pagination_token = None
while True:
    reviews = reviews_all(
        'com.dibd.bhashini',
        sleep_milliseconds=0,
        lang='en_IN',
        country='IN',
        sort=Sort.NEWEST,
    )

    # Process the reviews

    if not reviews:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-5bbe50e6e8ca> in <cell line: 2>()
#       1 pagination_token = None
#       2 while True:
# ----> 3     reviews = reviews_all(
#       4         'com.dibd.bhashini',
#       5         sleep_milliseconds=0,
#
# /usr/local/lib/python3.10/dist-packages/google_play_scraper/features/reviews.py in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     149
#     150     while True:
# --> 151         _result, continuation_token = reviews(
#     152             app_id,
#     153             count=MAX_COUNT_EACH_FETCH,
#
# /usr/local/lib/python3.10/dist-packages/google_play_scraper/features/reviews.py in reviews(app_id, lang, country, sort, count, filter_score_with, filter_device_with, continuation_token)
#     105
#     106         try:
# --> 107             review_items, token = _fetch_review_items(
# ...
